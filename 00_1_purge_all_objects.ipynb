# %% [markdown]
# Purge Azure Files

# %% [markdown]
# Landing Zone

# %%
dbutils.fs.rm("abfss://data-lake@storagetelcopoc2026.dfs.core.windows.net/landing/", recurse=True)

# %% [markdown]
# Raw Zone

# %%
dbutils.fs.rm("abfss://data-lake@storagetelcopoc2026.dfs.core.windows.net/00-raw/", recurse=True)

# %% [markdown]
# Bronze Zone

# %%
# %sql
-- U SQL ćeliji ili preko spark.sql()
DROP TABLE IF EXISTS telco_prod.`01-bronze`.mobile_measurements;

# %%
# %sql
DESCRIBE DETAIL telco_prod.`01-bronze`.mobile_measurements;

# %%
dbutils.fs.rm("abfss://data-lake@storagetelcopoc2026.dfs.core.windows.net/01-bronze/", recurse=True)

# %%
dbutils.fs.rm("abfss://data-lake@storagetelcopoc2026.dfs.core.windows.net/01-bronze/mobile_measurements", recurse=True)
