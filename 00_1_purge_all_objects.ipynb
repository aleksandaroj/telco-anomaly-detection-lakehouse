# %% [markdown]
# Purge Azure Files

# %% [markdown]
# Raw Zone

# %%
dbutils.fs.rm("abfss://data-lake@storagetelcopoc2026.dfs.core.windows.net/00-raw/", recurse=True)

# %% [markdown]
# Bronze Zone

# %%
# %sql
DROP TABLE IF EXISTS telco_prod.`01-bronze`.mobile_measurements_autoloader;
DROP TABLE IF EXISTS telco_prod.`01-bronze`.mobile_measurements_batch;

# %%
dbutils.fs.rm("abfss://data-lake@storagetelcopoc2026.dfs.core.windows.net/01-bronze/", recurse=True)

# %%
dbutils.fs.rm("abfss://data-lake@storagetelcopoc2026.dfs.core.windows.net/01-bronze/mobile_measurements_batch", recurse=True)
dbutils.fs.rm("abfss://data-lake@storagetelcopoc2026.dfs.core.windows.net/01-bronze/mobile_measurements_autoloader", recurse=True)
dbutils.fs.rm("abfss://data-lake@storagetelcopoc2026.dfs.core.windows.net/01-bronze/mobile_measurements__checkpoints", recurse=True)
