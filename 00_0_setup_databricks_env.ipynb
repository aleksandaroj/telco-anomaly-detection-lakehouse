# %%
# %sql

USE CATALOG telco_prod;

CREATE SCHEMA IF NOT EXISTS `01-bronze`;
CREATE SCHEMA IF NOT EXISTS `02-silver`;
CREATE SCHEMA IF NOT EXISTS `03-gold`;
