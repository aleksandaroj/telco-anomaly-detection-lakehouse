# %%
dbutils.widgets.text("base_path", "abfss://data-lake@storagetelcopoc2026.dfs.core.windows.net/")

base_path = dbutils.widgets.get("base_path")

paths = {
    "raw": f"{base_path}00-raw/",
    "bronze": f"{base_path}01-bronze/",
    "silver": f"{base_path}02-silver/",
    "gold": f"{base_path}03-gold/"}

print(paths)

# %% [markdown]
# Listanje Azure kontejnera preko SQL

# %%
# %sql
LIST 'abfss://data-lake@storagetelcopoc2026.dfs.core.windows.net/'

# %%
display(dbutils.fs.ls("abfss://data-lake@storagetelcopoc2026.dfs.core.windows.net/01-bronze/"))
